# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import pandas as pd

# %% [markdown]
# My classes are HC(healthy control), PD(parkinsons), and Parkinsonism (MSE and PSP)

# %% [markdown]
# Example spectrogram conversion

# %%
# example for one file
y, sr = librosa.load("D:/data science project/d/wav/h/HC1a1.wav")
librosa.display.waveshow(y, sr=sr)
print(f"Sample rate: {sr}")
print(f"Duration: {len(y) / sr:.2f} seconds")
# Out:
# Sample rate: 22050
# Duration: 19.69 seconds

# %%
# looping through the directory and creating spectrograms, change the paths 
directory = "D:/data science project/d/wav/pd/"
output_directory = "D:/data science project/d/spectrograms/pd/"

if not os.path.exists(output_directory):
    os.makedirs(output_directory)


wav_files = glob.glob(os.path.join(directory, "*.wav"))
print(f"Number of WAV files: {len(wav_files)}")

for wav_file in wav_files:

    y, sr = librosa.load(wav_file)
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr)

    png_file = os.path.join(output_directory, os.path.basename(wav_file).replace(".wav", ".png"))
    plt.savefig(png_file)
    plt.close()
print("PNG files created:")
for png_file in os.listdir(output_directory):
    if png_file.endswith(".png"):
        print(png_file)
# Out:
# Number of WAV files: 279
# PNG files created:
# PD10a1.png
# PD10a1_clean.png
# PD10a1_LF.png
# PD10a2.png
# PD10a2_clean.png
# PD10a2_LF.png
# PD10a3.png
# PD10a3_clean.png
# PD10a3_LF.png
# PD10i1.png
# PD10i1_clean.png
# PD10i1_LF.png
# PD10i2.png
# PD10i2_clean.png
# PD10i2_LF.png
# PD11a1.png
# PD11a1_clean.png
# PD11a1_LF.png
# PD11a2.png
# PD11a2_clean.png
# PD11a2_LF.png
# PD11i1.png
# PD11i1_clean.png
# PD11i1_LF.png
# PD11i2.png
# PD11i2_clean.png
# PD11i2_LF.png
# PD12a1.png
# PD12a1_clean.png
# PD12a1_LF.png
# PD12a2.png
# PD12a2_clean.png
# PD12a2_LF.png
# PD12i1.png
# PD12i1_clean.png
# PD12i1_LF.png
# PD12i2.png
# PD12i2_clean.png
# PD12i2_LF.png
# PD13a1.png
# PD13a1_clean.png
# PD13a1_LF.png
# PD13a2.png
# PD13a2_clean.png
# PD13a2_LF.png
# PD13i1.png
# PD13i1_clean.png
# PD13i1_LF.png
# PD13i2.png
# PD13i2_clean.png
# PD13i2_LF.png
# PD14a1.png
# PD14a1_clean.png
# PD14a1_LF.png
# PD14a2.png
# PD14a2_clean.png
# PD14a2_LF.png
# PD14i1.png
# PD14i1_clean.png
# ...

# %% [markdown]
# Example with other steps

# %%
# i am not too sure about this part
y, sr = librosa.load("D:/data science project/d/wav/h/HC1a1.wav", sr=None)

n_fft = 2048
hop_length = 512
n_mels = 128
fmax = 8000

S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft,
                                   hop_length=hop_length, n_mels=n_mels, fmax=fmax)

S_dB = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(3, 3))
librosa.display.specshow(S_dB, sr=sr, hop_length=hop_length,
                         cmap='magma', x_axis=None, y_axis=None)
plt.axis('off')
plt.tight_layout(pad=0)
# plt.savefig("HC1a1_spectrogram.png", bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# we can add other processing steps, there is a lot of info https://khareanu1612.medium.com/audio-signal-processing-with-spectrograms-and-librosa-b66a0a6bc5cc ; we might need fourier transform, and or other methods
