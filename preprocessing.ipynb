# %%
import os
import pandas as pd
import numpy as np
import librosa
from scipy.stats import variation

# paths
DATASET_CSV = "dataset.csv"
RECORDS_DIR = "records\records"  #this is the folder with all recorded files, with the all the original content

# loading the dataset
df = pd.read_csv(DATASET_CSV)

# %%
# first, extract group, subject ID, vowel, and repetition from code
counter=0
def parse_code(code):
    import re
    match = re.match(r"([A-Z]+)(\d+)([ai])(\d+)", code)
    if match:
        group, subject_id, vowel, repetition = match.groups()
        global counter
        counter=counter+1
        return group, int(subject_id), vowel, int(repetition)
    else:
        return None, None, None, None

df[['Group', 'SubjectID', 'Vowel', 'Repetition']] = df['record'].apply(
    lambda x: pd.Series(parse_code(x))
)
print(counter)
df.head()
# Out:
# 249
#     record subject group vowel    jitter    shimmer     HNR       SHR Group  \
# 88  MSA1a1    MSA1   MSA     a  3.927492  14.891001   7.819  0.357575   MSA
# 89  MSA1a2    MSA1   MSA     a  0.869565   4.198910  17.231  0.346014   MSA
# 90  MSA1i1    MSA1   MSA     i  0.983607   5.561001  22.601  0.000000   MSA
# 91  MSA1i2    MSA1   MSA     i  0.671141   7.316001  21.113  0.000000   MSA
# 92  MSA2a1    MSA2   MSA     a  1.704545  12.626999  12.537  0.695362   MSA
#
#     SubjectID Vowel  Repetition  Label  ImpulseJitterSTD  ImpulseShimmerCV  \
# 88          1     a           1    1.0               NaN               NaN
# 89          1     a           2    1.0               NaN               NaN
# 90          1     i           1    1.0               NaN               NaN
# 91          1     i           2    1.0               NaN               NaN
# 92          2     a           1    1.0               NaN               NaN
#
#     HasSubharmonics
# 88                0
# 89                0
# 90                0
# 91                0
# 92                0

# %%
# add labels to all groups (0 is healthy)
def label(row):
    if row['Group'] == 'PD':
        return 2
    elif row['Group'] in ['MSA', 'PSP']:
        return 1
    elif row['Group'] == 'HC':
        return 
    else:
        return np.nan  
df['Label'] = df.apply(label, axis=1)
df = df.dropna(subset=['Label'])

# %%
# add features from impulses.csv and subharmonics.csv from each file separately
def load_impulse_features(code):
    impulse_path = os.path.join(RECORDS_DIR, f"{code}_impulses.csv")
    if not os.path.exists(impulse_path):
        print(f"Missing: {impulse_path}")
        return pd.Series([np.nan, np.nan])
    df_imp = pd.read_csv(impulse_path, header=None, names=['Time', 'Amplitude'])
    times = df_imp['Time'].diff().dropna()
    amplitudes = df_imp['Amplitude']
    jitter_std = times.std()
    shimmer_cv = variation(amplitudes)
    return pd.Series([jitter_std, shimmer_cv])

def subharmonic_presence(code):
    path = os.path.join(RECORDS_DIR, f"{code}_subharmonics.csv")
    return int(os.path.exists(path))


df[['ImpulseJitterSTD', 'ImpulseShimmerCV']] = df['record'].apply(lambda x: pd.Series(load_impulse_features(x)))
df['HasSubharmonics'] = df['record'].apply(lambda x: pd.Series(subharmonic_presence(x)))
#old code, also did not work
#df[['ImpulseJitterSTD', 'ImpulseShimmerCV']] = df['record'].apply(load_impulse_features)
# df['HasSubharmonics'] = df['record'].apply(subharmonic_presence)
# Out:
# ecords\MSA1a1_impulses.csv
# ecords\MSA1a2_impulses.csv
# ecords\MSA1i1_impulses.csv
# ecords\MSA1i2_impulses.csv
# ecords\MSA2a1_impulses.csv
# ecords\MSA2a2_impulses.csv
# ecords\MSA2i1_impulses.csv
# ecords\MSA2i2_impulses.csv
# ecords\MSA3a1_impulses.csv
# ecords\MSA3a2_impulses.csv
# ecords\MSA3i1_impulses.csv
# ecords\MSA3i2_impulses.csv
# ecords\MSA4a1_impulses.csv
# ecords\MSA4a2_impulses.csv
# ecords\MSA4i1_impulses.csv
# ecords\MSA4i2_impulses.csv
# ecords\MSA5a1_impulses.csv
# ecords\MSA5a2_impulses.csv
# ecords\MSA5i1_impulses.csv
# ecords\MSA5i2_impulses.csv
# ecords\MSA6a1_impulses.csv
# ecords\MSA6a2_impulses.csv
# ecords\MSA6i1_impulses.csv
# ecords\MSA6i2_impulses.csv
# ecords\MSA7a1_impulses.csv
# ecords\MSA7a2_impulses.csv
# ecords\MSA7i1_impulses.csv
# ecords\MSA7i2_impulses.csv
# ecords\MSA8a1_impulses.csv
# ecords\MSA8a2_impulses.csv
# ecords\MSA8i1_impulses.csv
# ecords\MSA8i2_impulses.csv
# ecords\MSA9a1_impulses.csv
# ecords\MSA9a2_impulses.csv
# ecords\MSA9i1_impulses.csv
# ecords\MSA9i2_impulses.csv
# ecords\MSA10a1_impulses.csv
# ecords\MSA10a2_impulses.csv
# ecords\MSA10i1_impulses.csv
# ecords\MSA10i2_impulses.csv
# ecords\MSA11a1_impulses.csv
# ecords\MSA11a2_impulses.csv
# ecords\MSA11i1_impulses.csv
# ecords\MSA11i2_impulses.csv
# ecords\MSA12a1_impulses.csv
# ecords\MSA12a2_impulses.csv
# ecords\MSA12i1_impulses.csv
# ecords\MSA12i2_impulses.csv
# ecords\MSA13a1_impulses.csv
# ecords\MSA13a2_impulses.csv
# ecords\MSA13i1_impulses.csv
# ecords\MSA13i2_impulses.csv
# ecords\MSA14a1_impulses.csv
# ecords\MSA14a2_impulses.csv
# ecords\MSA14i1_impulses.csv
# ecords\MSA14i2_impulses.csv
# ecords\MSA15a1_impulses.csv
# ecords\MSA15a2_impulses.csv
# ecords\MSA15i1_impulses.csv
# ecords\MSA15i2_impulses.csv
# ecords\MSA16a1_impulses.csv
# ecords\MSA16a2_impulses.csv
# ecords\MSA16i1_impulses.csv
# ecords\MSA16i2_impulses.csv
# ecords\MSA17a1_impulses.csv
# ecords\MSA17a2_impulses.csv
# ecords\MSA17i1_impulses.csv
# ecords\MSA17i2_impulses.csv
# ecords\MSA18a1_impulses.csv
# ecords\MSA18a2_impulses.csv
# ecords\MSA18i1_impulses.csv
# ecords\MSA18i2_impulses.csv
# ecords\MSA19a1_impulses.csv
# ecords\MSA19a2_impulses.csv
# ecords\MSA19i1_impulses.csv
# ecords\MSA19i2_impulses.csv
# ecords\MSA20a1_impulses.csv
# ecords\MSA20a2_impulses.csv
# ecords\MSA20i1_impulses.csv
# ecords\MSA20i2_impulses.csv
# ecords\MSA21a1_impulses.csv
# ecords\MSA21a2_impulses.csv
# ecords\MSA21i1_impulses.csv
# ecords\MSA21i2_impulses.csv
# ecords\PD1a1_impulses.csv
# ecords\PD1a2_impulses.csv
# ecords\PD1i1_impulses.csv
# ecords\PD1i2_impulses.csv
# ecords\PD2a1_impulses.csv
# ecords\PD2a2_impulses.csv
# ecords\PD2i1_impulses.csv
# ecords\PD2i2_impulses.csv
# ecords\PD3a1_impulses.csv
# ecords\PD3a2_impulses.csv
# ecords\PD3a3_impulses.csv
# ecords\PD3i1_impulses.csv
# ecords\PD3i2_impulses.csv
# ecords\PD4a1_impulses.csv
# ecords\PD4a2_impulses.csv
# ecords\PD4i1_impulses.csv
# ecords\PD4i2_impulses.csv
# ecords\PD5a1_impulses.csv
# ecords\PD5a2_impulses.csv
# ecords\PD5a3_impulses.csv
# ecords\PD5i1_impulses.csv
# ecords\PD5i2_impulses.csv
# ecords\PD6a1_impulses.csv
# ecords\PD6a2_impulses.csv
# ecords\PD6i1_impulses.csv
# ecords\PD6i2_impulses.csv
# ecords\PD7a1_impulses.csv
# ecords\PD7a2_impulses.csv
# ecords\PD7i1_impulses.csv
# ecords\PD7i2_impulses.csv
# ecords\PD8a1_impulses.csv
# ecords\PD8a2_impulses.csv
# ecords\PD8i1_impulses.csv
# ecords\PD8i2_impulses.csv
# ecords\PD9a1_impulses.csv
# ecords\PD9a2_impulses.csv
# ecords\PD9i1_impulses.csv
# ecords\PD9i2_impulses.csv
# ecords\PD10a1_impulses.csv
# ecords\PD10a2_impulses.csv
# ecords\PD10a3_impulses.csv
# ecords\PD10i1_impulses.csv
# ecords\PD10i2_impulses.csv
# ecords\PD11a1_impulses.csv
# ecords\PD11a2_impulses.csv
# ecords\PD11i1_impulses.csv
# ecords\PD11i2_impulses.csv
# ecords\PD12a1_impulses.csv
# ecords\PD12a2_impulses.csv
# ecords\PD12i1_impulses.csv
# ecords\PD12i2_impulses.csv
# ecords\PD13a1_impulses.csv
# ecords\PD13a2_impulses.csv
# ecords\PD13i1_impulses.csv
# ecords\PD13i2_impulses.csv
# ecords\PD14a1_impulses.csv
# ecords\PD14a2_impulses.csv
# ecords\PD14i1_impulses.csv
# ecords\PD14i2_impulses.csv
# ecords\PD15a1_impulses.csv
# ecords\PD15a2_impulses.csv
# ecords\PD15i1_impulses.csv
# ecords\PD15i2_impulses.csv
# ecords\PD16a1_impulses.csv
# ecords\PD16a2_impulses.csv
# ecords\PD16i1_impulses.csv
# ecords\PD16i2_impulses.csv
# ecords\PD17a1_impulses.csv
# ecords\PD17a2_impulses.csv
# ecords\PD17i1_impulses.csv
# ecords\PD17i2_impulses.csv
# ecords\PD18a1_impulses.csv
# ecords\PD18a2_impulses.csv
# ecords\PD18i1_impulses.csv
# ecords\PD18i2_impulses.csv
# ecords\PD19a1_impulses.csv
# ecords\PD19a2_impulses.csv
# ecords\PD19i1_impulses.csv
# ecords\PD19i2_impulses.csv
# ecords\PD20a1_impulses.csv
# ecords\PD20a2_impulses.csv
# ecords\PD20i1_impulses.csv
# ecords\PD20i2_impulses.csv
# ecords\PD21a1_impulses.csv
# ecords\PD21a2_impulses.csv
# ecords\PD21i1_impulses.csv
# ecords\PD21i2_impulses.csv
# ecords\PD22a1_impulses.csv
# ecords\PD22a2_impulses.csv
# ecords\PD22a3_impulses.csv
# ecords\PD22i1_impulses.csv
# ecords\PD22i2_impulses.csv
# ecords\PD22i3_impulses.csv
# ecords\PSP1a1_impulses.csv
# ecords\PSP1a2_impulses.csv
# ecords\PSP1i1_impulses.csv
# ecords\PSP1i2_impulses.csv
# ecords\PSP2a1_impulses.csv
# ecords\PSP2a2_impulses.csv
# ecords\PSP2i1_impulses.csv
# ecords\PSP2i2_impulses.csv
# ecords\PSP3a1_impulses.csv
# ecords\PSP3a2_impulses.csv
# ecords\PSP3i1_impulses.csv
# ecords\PSP3i2_impulses.csv
# ecords\PSP4a1_impulses.csv
# ecords\PSP4a2_impulses.csv
# ecords\PSP4i1_impulses.csv
# ecords\PSP4i2_impulses.csv
# ecords\PSP5a1_impulses.csv
# ecords\PSP5a2_impulses.csv
# ecords\PSP5i1_impulses.csv
# ecords\PSP5i2_impulses.csv
# ecords\PSP6a1_impulses.csv
# ecords\PSP6a2_impulses.csv
# ecords\PSP6i1_impulses.csv
# ecords\PSP6i2_impulses.csv
# ecords\PSP7a1_impulses.csv
# ecords\PSP7a2_impulses.csv
# ecords\PSP7i1_impulses.csv
# ecords\PSP7i2_impulses.csv
# ecords\PSP8a1_impulses.csv
# ecords\PSP8a2_impulses.csv
# ecords\PSP8i1_impulses.csv
# ecords\PSP8i2_impulses.csv
# ecords\PSP9a1_impulses.csv
# ecords\PSP9a2_impulses.csv
# ecords\PSP9i1_impulses.csv
# ecords\PSP9i2_impulses.csv
# ecords\PSP10a1_impulses.csv
# ecords\PSP10a2_impulses.csv
# ecords\PSP10i1_impulses.csv
# ecords\PSP10i2_impulses.csv
# ecords\PSP11a1_impulses.csv
# ecords\PSP11a2_impulses.csv
# ecords\PSP11i1_impulses.csv
# ecords\PSP11i2_impulses.csv
# ecords\PSP12a1_impulses.csv
# ecords\PSP12a2_impulses.csv
# ecords\PSP12i1_impulses.csv
# ecords\PSP12i2_impulses.csv
# ecords\PSP13a1_impulses.csv
# ecords\PSP13a2_impulses.csv
# ecords\PSP13i1_impulses.csv
# ecords\PSP13i2_impulses.csv
# ecords\PSP14a1_impulses.csv
# ecords\PSP14a2_impulses.csv
# ecords\PSP14i1_impulses.csv
# ecords\PSP14i2_impulses.csv
# ecords\PSP15a1_impulses.csv
# ecords\PSP15a2_impulses.csv
# ecords\PSP15i1_impulses.csv
# ecords\PSP15i2_impulses.csv
# ecords\PSP16a1_impulses.csv
# ecords\PSP16a2_impulses.csv
# ecords\PSP16i1_impulses.csv
# ecords\PSP16i2_impulses.csv
# ecords\PSP17a1_impulses.csv
# ecords\PSP17a2_impulses.csv
# ecords\PSP17i1_impulses.csv
# ecords\PSP17i2_impulses.csv
# ecords\PSP18a1_impulses.csv
# ecords\PSP18a2_impulses.csv
# ecords\PSP18i1_impulses.csv
# ecords\PSP18i2_impulses.csv

# %%
# extract features from clean waveform
def extract_audio_features(code):
    filepath = os.path.join(RECORDS_DIR, f"{code}_clean.wav")
    if not os.path.exists(filepath):
        return pd.Series([np.nan] * 5)
    y, sr = librosa.load(filepath)
    
    f0, voiced_flag, voiced_probs = librosa.pyin(y, fmin=75, fmax=400)
    f0_clean = f0[~np.isnan(f0)]
    if len(f0_clean) == 0:
        return pd.Series([np.nan] * 5)
    f0_mean = np.mean(f0_clean)
    f0_std = np.std(f0_clean)
    f0_range = np.max(f0_clean) - np.min(f0_clean)

    hnr = librosa.effects.harmonic(y)
    hnr_ratio = np.mean(hnr)

    return pd.Series([f0_mean, f0_std, f0_range, hnr_ratio, len(f0_clean)])

df[['F0_mean', 'F0_std', 'F0_range', 'HNR_est', 'VoicedLen']] = df['record'].apply(lambda x: pd.Series(extract_audio_features(x)))

# %%
features = [
    'jitter', 'shimmer', 'HNR', 'SHR',
    'ImpulseJitterSTD', 'ImpulseShimmerCV', 'HasSubharmonics',
    'F0_mean', 'F0_std', 'F0_range', 'HNR_est', 'VoicedLen'
]

agg_df = df.groupby(['Group', 'SubjectID', 'Label'])[features].mean().reset_index()
agg_df.to_csv("processed_dataset_withhealthy.csv", index=False)

print('dataset produced')
# Out:
# dataset produced
